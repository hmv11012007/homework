# %% [markdown]
# Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diện tích và chu
# vi của nó.

# %%
a,b=map(float,input().split( ))
P=(a+b)/2
S=a*b
print (f"chu vi la {P}")
print (f"dien tich la {S}")
# Out:
# chu vi la 2.5
# dien tich la 6.0

# %% [markdown]
# Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của
# nó.

# %%
a= float(input())
P=2*a*3.14
S=3.14*a
print (f"chu vi la {P}")
print (f"dien tich la {S}")
# Out:
# chu vi la 18.84
# dien tich la 9.42

# %% [markdown]
# Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểm tra xem nó có thể là
# độ dài ba cạnh hay không, nếu  không thì in  ra màn  hình  'Khong la ba  canh
# cua mot tam  giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân,
# Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn
# hình.

# %%
import math
try:
    a = float(input("Nhập cạnh a: "))
    b = float(input("Nhập cạnh b: "))
    c = float(input("Nhập cạnh c: "))
    if (a + b > c) and (a + c > b) and (b + c > a):
        print("Đây là ba cạnh của một tam giác.")
        loai_tg = ""
        if a == b == c:
            loai_tg = "Đều"
        elif (a**2 + b**2 == c**2) or (a**2 + c**2 == b**2) or (b**2 + c**2 == a**2):
            if a == b or b == c or a == c:
                loai_tg = "Vuông Cân"
            else:
                loai_tg = "Vuông"
            loai_tg = "Cân"
        else:
            loai_tg = "Thường"     
        print(f"Loại tam giác: {loai_tg}")
        chu_vi = a + b + c
        p = chu_vi / 2  
        dien_tich = math.sqrt(p * (p - a) * (p - b) * (p - c))

        print(f"Chu vi tam giác: {chu_vi}")
        print(f"Diện tích tam giác: {dien_tich:.2f}")
        
    else:
        print("Khong la ba canh cua mot tam giac")

except ValueError:
    print("Vui lòng nhập số hợp lệ.")
# Out:
# Đây là ba cạnh của một tam giác.
# Loại tam giác: Cân
# Chu vi tam giác: 12.0
# Diện tích tam giác: 6.00

# %% [markdown]
# Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a,b=map(float,input().split( ))
print(f"phuong trinh là {a}x +{b} =0")
if a!=0:
    x=b/a
    print(f"phuong trinh co nghiem la x={x:.2f}")
else:
    if b==0:
        print("phuong trinh vo so nghiem")
    else:
        print("phuong trinh vo nghiem")
# Out:
# phuong trinh là 5.0x +6.0 =0
# phuong trinh co nghiem la x=1.20

# %% [markdown]
# Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
a,b,c=map(float,input().split( ))
print(f"phương trinh co dang la {a}x2+{b}x+{c}=0")
if a==0:
    if b==0:
        if c==0:
            print("phuong trinh co vo so nghiem")
        else:
            print("phuong trinh vo nghiem")
    else:
        x=-c/b
        print(f"phuong trinh co nghiem duy nhat x={x}")
else:
    delta=b**2-4*a*c
    print(f"Delta={delta}")
    if delta <0:
        print("phuong trinh vo nghiem")
    elif delta==0:
        x=-b/(2*a)
        print(f"phuong trinh co nghiem duy nhat x={x}")
    else:
        x1=(-b+math.sqrt(delta))/(2*a)
        x2=(-b-math.sqrt(delta))/(2*a)
        print(f"phuong trinh co 2 nghien phan biet x1={x1} va x2={x2}")
# Out:
# phương trinh co dang la 5.0x2+6.0x+7.0=0
# Delta=-104.0
# phuong trinh vo nghiem

# %% [markdown]
# Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a,b,c,d= map(int,input().split( ))
print(max(a,b,c,d))

# %%
a,b,c,d= map(float,input().split( ))
max_val=a
if b> max_val:
    max_val=b
if c> max_val:
    max_val =c
if d> max_val:
    max_val= d
print(f"gia tri lon nhat trong 4 so la {max_val}")
# Out:
# gia tri lon nhat trong 4 so la 4.0

# %% [markdown]
# Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bàn phím).

# %%
a,b,c,d,= map(int,input().split( ))
print(min(a,b,c,d))
# Out:
# 4

# %%
a,b,c,d= map(float,input().split( ))
min_val=a
if b<min_val:
    min_val=b
if c< min_val:
    min_val =c
if c< min_val:
    min_val= d
print(f"gia tri nho nhat trong 4 so la {min_val}")
# Out:
# gia tri nho nhat trong 4 so la 1.0

# %% [markdown]
# Bài 8: Giải hệ phương trình tuyến tính:
# ax + by= m
# cx + dy = n

# %%
a,b,c,d,m,n= map(float,input().split( ))
D=a*d-b*c
Dx=b*n-d*m
Dy=a*n-m*c
if D!=0:
    x=Dx/D
    y=Dy/D
    print(f"phuong trinh co nghiem x={x} va y={y}")
else:
    if Dx==0 or Dy==0:
        print("phuong trinh vo so nghiem")
    else:
        print("phuong trinh vo nghiem")
# Out:
# phuong trinh co nghiem x=4.0 va y=4.5

# %% [markdown]
# Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết
# ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao
# nhiêu giây.

# %%
x=float(input())
gio=x//3600
phut = (x % 3600) // 60
giay = x % 60
tg=f"{gio:.2f} {phut:.2f} {giay:.2f}"
print("-" * 20)
print(f"ket qua chuyen doi la {tg}")
print("-" * 20)
# Out:
# --------------------
# ket qua chuyen doi la 0.00 0.00 50.00
# --------------------

# %% [markdown]
# Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vào một
# điểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
xi=float(input("hoành độ tâm I"))
yi=float(input("tung độ tâm I"))
r=float(input("bán kính đường tròn"))
xa=float(input("hoành độ A"))
ya=float(input("tung độ A"))
khoang_cach= (xa-xi)**2+(ya-yi)**2
R=r**2
if khoang_cach==R:
    print(" A thuộc đường tròn tâm I")
elif khoang_cach<R:
    print("A nằm trong đường tròn tâm I")
else:
    print("A nằm ngoài đường tròn tâm I")
# Out:
# A nằm trong đường tròn tâm I

# %%
Bài 11: Tính xy (Với x, y là số thực).

# %%
x,y=map(float,input().split( ))
a=x**y
print(f"{a}")
# Out:
# 15625.0
